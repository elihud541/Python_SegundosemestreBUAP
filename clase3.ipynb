# %%
class Coche():
    def __init__(self, marca, mod, año, col):
        self.marca = marca
        self.modelo=mod
        self.año=año
        self.color=col
        
    def descripcion(self):
        print(f"Este coche es de color {self.color} de la marca {self.marca} y modelo {self.modelo} del año {self.año}")

# %%
lista = [
    Coche("Ford", "Mustang", 2020, "Azul"),
    Coche("Tesla", "Model 3", 2022, "Blanco"),
    Coche("Toyota", "Corolla", 2019, "Plateado"),
    Coche("Honda", "Civic", 2021, "Negro"),
    Coche("Chevrolet", "Camaro", 2018, "Amarillo"),
    Coche("BMW", "M3", 2023, "Verde"),
    Coche("Audi", "A4", 2020, "Gris"),
    Coche("Volkswagen", "Golf", 2017, "Rojo"),
    Coche("Mercedes-Benz", "Clase C", 2022, "Azul Marino"),
    Coche("Nissan", "GT-R", 2015, "Blanco"),
    Coche("Porsche", "911 Carrera", 2021, "Crayón"),
    Coche("Hyundai", "Elantra", 2020, "Azul"),
    Coche("Kia", "Stinger", 2022, "Naranja"),
    Coche("Mazda", "MX-5 Miata", 2019, "Rojo Alma"),
    Coche("Subaru", "WRX", 2021, "Azul WR"),
    Coche("Lexus", "IS 350", 2023, "Plata"),
    Coche("Dodge", "Challenger", 2018, "Morado"),
    Coche("Jeep", "Wrangler", 2022, "Verde Militar"),
    Coche("Ferrari", "488 GTB", 2019, "Rojo"),
    Coche("Lamborghini", "Huracan", 2020, "Amarillo"),
    Coche("McLaren", "720S", 2021, "Naranja"),
    Coche("Aston Martin", "Vantage", 2022, "Verde"),
    Coche("Jaguar", "F-Type", 2021, "Blanco"),
    Coche("Land Rover", "Defender", 2023, "Arena"),
    Coche("Volvo", "XC90", 2020, "Negro"),
    Coche("Mitsubishi", "Lancer Evo X", 2015, "Rojo"),
    Coche("Mini", "Cooper S", 2022, "Verde Británico"),
    Coche("Fiat", "500 Abarth", 2018, "Blanco"),
    Coche("Alfa Romeo", "Giulia", 2021, "Rojo"),
    Coche("Cadillac", "CT5-V Blackwing", 2023, "Gris"),
    Coche("Buick", "Regal", 2019, "Azul"),
    Coche("GMC", "Sierra", 2022, "Negro"),
    Coche("Ram", "1500 TRX", 2021, "Rojo"),
    Coche("Peugeot", "208", 2022, "Amarillo"),
    Coche("Renault", "Clio", 2021, "Azul"),
    Coche("Seat", "Leon", 2020, "Blanco"),
    Coche("Skoda", "Octavia", 2021, "Azul"),
    Coche("Suzuki", "Swift Sport", 2022, "Amarillo"),
    Coche("Infiniti", "Q50", 2020, "Gris"),
    Coche("Acura", "NSX", 2017, "Rojo"),
    Coche("Genesis", "G70", 2022, "Blanco"),
    Coche("Rivian", "R1T", 2023, "Azul"),
    Coche("Lucid", "Air", 2022, "Dorado"),
    Coche("Lotus", "Emira", 2023, "Azul"),
    Coche("Bentley", "Continental GT", 2021, "Verde"),
    Coche("Rolls-Royce", "Ghost", 2022, "Negro"),
    Coche("Maserati", "MC20", 2023, "Blanco"),
    Coche("Bugatti", "Chiron", 2018, "Azul"),
    Coche("Pagani", "Huayra", 2016, "Fibra de Carbono"),
    Coche("Koenigsegg", "Jesko", 2023, "Blanco")
]

for s in lista:
    s.descripcion()
# Out:
# Este coche es de color Azul de la marca Ford y modelo Mustang del año 2020
# Este coche es de color Blanco de la marca Tesla y modelo Model 3 del año 2022
# Este coche es de color Plateado de la marca Toyota y modelo Corolla del año 2019
# Este coche es de color Negro de la marca Honda y modelo Civic del año 2021
# Este coche es de color Amarillo de la marca Chevrolet y modelo Camaro del año 2018
# Este coche es de color Verde de la marca BMW y modelo M3 del año 2023
# Este coche es de color Gris de la marca Audi y modelo A4 del año 2020
# Este coche es de color Rojo de la marca Volkswagen y modelo Golf del año 2017
# Este coche es de color Azul Marino de la marca Mercedes-Benz y modelo Clase C del año 2022
# Este coche es de color Blanco de la marca Nissan y modelo GT-R del año 2015
# Este coche es de color Crayón de la marca Porsche y modelo 911 Carrera del año 2021
# Este coche es de color Azul de la marca Hyundai y modelo Elantra del año 2020
# ...

# %%
#Que hace el código?

class App():
    def __init__(self,usuarios,capacidad,nombreusuario):
        self.usuarios=usuarios
        self.capacidad= capacidad
        self.nombreusuario=nombreusuario
        
    def login(self):
        if self.nombreusuario == "Dueño" and self.usuarios>=1:
            print(f"Bienvenido {self.nombreusuario}")
            print(f"Tu capacidad es de {self.capacidad}")
            
    def incremetar(self, numero):
        self.capacidad+=numero
        return self.capacidad
    
us1 =App(35,256,"Dueño")
us1.login()
us1.incremetar(50)
print(us1.capacidad)

us2=App(40, 245, "Alan")
us2.login()
# Out:
# Bienvenido Dueño
# Tu capacidad es de 256
# 306

# %%
#Ejercicio

class Alumno():
    def __init__(self,nombre,matricula):
        self.nombre=nombre
        self.matricula=matricula
        self.calif=[]

    def agregar_calificacion(self,calificacion):
        self.calif.append(calificacion)
    
    def calcular_promedio(self):
        return sum(self.calif)/len(self.calif)
    
    def estado_final(self):
        promedio = self.calcular_promedio()
        return "Aprobado" if promedio >=7 else "Reprobado"

# %%
class Grupo():
    def __init__(self, nombre_grupo):
        self.nombre_grupo= nombre_grupo
        self.alumnos = []
    
    def agregar_alumnos(self, alumno):
        self.alumnos.append(alumno)
    
    def mostrar_promedio(self):
        print(f"Promedios del grupo {self.nombre_grupo}:")
        for alumno in self.alumnos:
            promedio = alumno.calcular_promedio()
            estado = alumno.estado_final()
            print(f"{alumno.nombre} ({alumno.matricula}): Promedio = {promedio:.2f}, Estado = {estado}")
    
    def mejor_alumno(self):
        if not self.alumnos:
            print("No hay alumnos en el grupo")
            return None
        
        mejor=max(self.alumnos, key=lambda alumno: alumno.calcular_promedio())
        print(f"El mejor alumno es {mejor.nombre} ({mejor.matricula}) con un promedio de {mejor.calcular_promedio():.2f}")

# %%
alumno1=Alumno("Caro Sanchez", 12345)
alumno2=Alumno("Ali Lopez", 54321)
alumno3=Alumno("Richi Malo", 66666)

# %%
alumno1.agregar_calificacion(9.5)
alumno1.agregar_calificacion(8)
alumno1.agregar_calificacion(8.5)

alumno2.agregar_calificacion(10)
alumno2.agregar_calificacion(10)

alumno3.agregar_calificacion(6)
alumno3.agregar_calificacion(6)
alumno3.agregar_calificacion(6)
alumno3.agregar_calificacion(6)

# %%
print(f"El alumno {alumno1.nombre} tiene promedio de: {alumno1.calcular_promedio():.2f} y esta {alumno1.estado_final()}")
print(f"El alumno {alumno2.nombre} tiene promedio de: {alumno2.calcular_promedio():.2f} y esta {alumno2.estado_final()}")
print(f"El alumno {alumno3.nombre} tiene promedio de: {alumno3.calcular_promedio():.2f} y esta {alumno3.estado_final()}")
# Out:
# El alumno Caro Sanchez tiene promedio de: 8.67 y esta Aprobado
# El alumno Ali Lopez tiene promedio de: 10.00 y esta Aprobado
# El alumno Richi Malo tiene promedio de: 6.00 y esta Reprobado
